# %% [markdown]
# # Virtual Internship Program at AINE AI
#
# ## Name: R.Valli Subha

# %% [markdown]
# ## Project 5: Essentials of Python Programming
#
# ### About the project:  The project leverages the basic concepts of Python programming such as variables, data types, loop and conditional statements to develop the game of Rock, Papers and Scissors.
#
# ### Project Title:  Developing ‘Rock, Paper and Scissors’ game using Python programming
#
# ### Aim:  Write a Python program to develop a Rock, Papers and Scissors game to be played against a computer.

# %% [markdown]
# ***The Objective of this task is to understand the environment of the Jupyter Notebook on Anaconda 3.
# I have learned the basic concepts of python like data types, lists, various libraries, loop statements and conditional operators that I have also implemented them in this program through my syntaxes.***

# %%
import random #To generate random numbers

print(f"\n Welcome to the game of Rock, Paper, Scissor along with Lizard and Spock.\n")  #Welcome message for the user player

total_count = int(input("\n how many turns of game you would like to play? \n")) 
#To get a numeric input to know how many times the user wants to play this game on loop

print("*"*70) #To have a neat segregation between outputs while presenting.

def main():  #To start an execution of the program

    options = ["rock", "paper", "scissors", "lizard", "spock"] 
    computer_choice = random.choice(options)   #To enable the system to make random choice among the options
    player_choice = input("\n Rock, Paper, Scissors, Lizard or Spock?\n ").lower()
    print("*"*70)

    while player_choice not in options or player_choice.isdigit(): 
        #To check whether the user provides an input as a digit 
        player_choice = input("\n This is an invalid input. Kindly refine your choice of input : \n ").lower()

    print(f"\n You have chosen {player_choice} and the computer has chosen {computer_choice}.\n")

    if player_choice == computer_choice:
        print(f"\n Both player and computer has selected {player_choice}. It's a tie!\n") 
        #When player and computer chose the same option. Its a tie
        print("*"*70)
        
#Following are the commands to produce the result when certain options are chosen by player as well as the computer.      
    
    elif player_choice == "rock":
        if computer_choice == "scissors":
            print(f"\n Rock smashes the scissors. So, You win!\n") 
        else:
            print(f"\n Paper covers the rock. So, You lose!\n")
        print("*"*70)
           
    elif player_choice == "paper":
        if computer_choice == "rock":
            print(f"\n Paper covers the rock. So, You win!\n")
        else:
            print(f"\n Scissors cuts the paper. So, You lose!\n")
        print("*"*70)
            
    elif player_choice == "scissors":
        if computer_choice == "paper":
            print(f"\n Scissors cuts the paper. So, You win!\n")
        else:
            print(f"\n Rock smashes the scissors. So, You lose!\n")
        print("*"*70)
            
    elif player_choice == "rock":
        if computer_choice == "lizard":
            print(f"\n Rock crushes the lizard. So, You win!\n")
        else:
            print (f"\n Spock vaporizes the rock. So, You lose!\n")
        print("*"*70)
            
    elif player_choice == "paper":
        if computer_choice == "spock":
            print(f"\n Paper disproves the spock. So, You win!\n")
        else:
            print (f"\n Lizard eats the paper. So, You lose!\n")
        print("*"*70)
            
    elif player_choice == "scissors":
        if computer_choice == "lizard":
            print(f"\n Scissors decapitates the lizard. So, You win!\n")
        else:
            print (f"\n Spock smashes the scissors. So, You lose!\n")
        print("*"*70)
            
    elif player_choice == "lizard":
        if computer_choice == "spock":
            print(f"\n Lizard poisons the spock. So, You win!\n")
        else:
            print (f"\n Scissors decapitates the lizard. So, You lose!\n")
        print("*"*70)
            
    elif player_choice == "spock":
        if computer_choice == "rock":
            print(f"\n Spock vaporizes the rock . So, You win!\n")
        else:
            print (f"\n Paper disproves the spock. So, You lose!\n")
        print("*"*70)
    
    
    return main

for count in range(0, total_count):    #To loop the function according to the no of turn that user player wants to play. 
    result = main()
    
print(f"\n Thanks for playing this game. Hope you enjoyed! \n")  # End wishes message
print("*"*70)
# Out:
#  Welcome to the game of Rock, Paper, Scissor along with Lizard and Spock.
#
#
#  how many turns of game you would like to play?
# 5
# **********************************************************************
#
#  Rock, Paper, Scissors, Lizard or Spock?
#  7
# **********************************************************************
#
#  This is an invalid input. Kindly refine your choice of input :
#  rock
#
#  You have chosen rock and the computer has chosen scissors.
#
#
#  Rock smashes the scissors. So, You win!
#
# **********************************************************************
#
#  Rock, Paper, Scissors, Lizard or Spock?
#  Scissors
# **********************************************************************
#
#  You have chosen scissors and the computer has chosen spock.
#
#
#  Rock smashes the scissors. So, You lose!
#
# **********************************************************************
#
#  Rock, Paper, Scissors, Lizard or Spock?
#  Spock
# ...
